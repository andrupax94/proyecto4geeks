# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_regression
from src.utils.config import *

# %%
# Cargamos el dataset
df = pd.read_csv(RAW_DIR  / 'dataset_finalV2.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Cargamos el dataset
# ----> 2 df = pd.read_csv(RAW_DIR  / 'dataset_finalV2.csv')
#       3 df.head()
#
# File c:\Users\totor\proyecto4geeks\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\totor\proyecto4geeks\.venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\totor\proyecto4geeks\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\totor\proyecto4geeks\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\totor\proyecto4geeks\.venv\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\totor\\proyecto4geeks\\data\\raw\\dataset_finalV2.csv'

# %%
# Imprimimos el numero de filas
print(f"Número de Filas en 'df': {len(df)}")

# Verificamos la cantidad de variables por tipos de datos en df que son los datos que vamos a aplicar en el EDA:
pd.Series.value_counts(df.dtypes)
# Out:
# Número de Filas en 'df': 129440
# str        12
# float64     5
# bool        3
# Name: count, dtype: int64

# %%
# Obtenemos qué columnas tienen valores nulos y porcentage respectivamente
print("------------------PORCENTAJE DE VALORES NULOS DEL df---------------------\n")
info_nulls = pd.DataFrame({
    '% Nullidad': df.isna().sum() / len(df) * 100
}).sort_values(by='% Nullidad', ascending = False)
info_nulls
# Out:
# ------------------PORCENTAJE DE VALORES NULOS DEL df---------------------
#                    % Nullidad
# env                100.000000
# labels              42.919084
# human_labels        42.919084
# bit_depth            0.010575
# bit_velocity         0.010575
# size                 0.003777
# sample_rate          0.003777
# date_modification    0.003777
# duration             0.003777
# audio_format         0.003777
# channels             0.003777
# audio                0.000000
# human_label          0.000000
# label                0.000000
# file_exists          0.000000
# emergency            0.000000
# path                 0.000000
# dataset_source       0.000000
# alertable            0.000000
# split                0.000000

# %%
df[df["size"].isna()].head()
# Out:
#                               audio                         label  \
# 71                  -QVqh513RxQ.m4a             /C/fight_9e6417eb
# 72                  -QVqh513RxQ.m4a     /C/gun_explosion_a0a388e0
# 130                 -mRz2kEp0ho.m4a  /C/instrument_music_b311b450
# 140                 -qovh3DNoX0.m4a     /C/gun_explosion_a0a388e0
# 120851  synthetic_001_1.00_4.40.wav            /C/crying_300aeae2
#
#                                   labels       human_label  \
# 71                 ["/C/fight_9e6417eb"]             fight
# 72         ["/C/gun_explosion_a0a388e0"]     gun_explosion
# 130     ["/C/instrument_music_b311b450"]  instrument_music
# 140        ["/C/gun_explosion_a0a388e0"]     gun_explosion
# 120851            ["/C/crying_300aeae2"]            crying
#
#                 human_labels  \
# 71                 ["fight"]
# 72         ["gun_explosion"]
# 130     ["instrument_music"]
# 140        ["gun_explosion"]
# 120851            ["crying"]
#
#                                                      path dataset_source  \
# 71      /home/andres/Documentos/proyecto4geeks/data/ra...        sonidos
# 72      /home/andres/Documentos/proyecto4geeks/data/ra...        sonidos
# 130     /home/andres/Documentos/proyecto4geeks/data/ra...        sonidos
# 140     /home/andres/Documentos/proyecto4geeks/data/ra...        sonidos
# 120851  /home/andres/Documentos/proyecto4geeks/data/ra...          VOICe
#
#         split  env  alertable  emergency  file_exists audio_format  duration  \
# 71      train  NaN       True       True         True          NaN       NaN
# 72      train  NaN       True       True         True          NaN       NaN
# 130     train  NaN      False      False         True          NaN       NaN
# 140     train  NaN       True       True         True          NaN       NaN
# 120851  train  NaN       True      False         True          NaN       NaN
#
#         sample_rate channels  bit_depth  bit_velocity  size date_modification
# 71              NaN      NaN        NaN           NaN   NaN               NaN
# 72              NaN      NaN        NaN           NaN   NaN               NaN
# 130             NaN      NaN        NaN           NaN   NaN               NaN
# 140             NaN      NaN        NaN           NaN   NaN               NaN
# 120851          NaN      NaN        NaN           NaN   NaN               NaN

# %%
df = df[df["size"].notna()]
df[df["size"].isna()]
# Out:
# Empty DataFrame
# Columns: [audio, label, labels, human_label, human_labels, path, dataset_source, split, env, alertable, emergency, file_exists, audio_format, duration, sample_rate, channels, bit_depth, bit_velocity, size, date_modification]
# Index: []

# %%
# Imprimimos el nímero de filas
print(f"Número de Filas en 'df': {len(df)}")

# Verificamos la cantidad de variables por tipos de datos en df que son los datos que vamos a aplicar en el EDA:
pd.Series.value_counts(df.dtypes)
# Out:
# Numero De Filas en 'df': 132379
# str        11
# float64     6
# bool        3
# Name: count, dtype: int64

# %%
# =========================
# CONFIGURACIÓN
# =========================

# Lista de columnas a analizar
def history_plot(df,columns_to_plot):

    # Número máximo de valores únicos a mostrar
    top_n = 40

    # =========================
    # GRÁFICOS
    # =========================

    # Crear figura dinámica
    fig, axes = plt.subplots(
        nrows=len(columns_to_plot),
        figsize=(12, 5 * len(columns_to_plot))
    )

    # Si solo hay una columna
    if len(columns_to_plot) == 1:
        axes = [axes]

    # Recorrer columnas
    for ax, col in zip(axes, columns_to_plot):

        # Conteo de valores únicos
        value_counts = (
            df[col]
            .astype(str)
            .value_counts()
            .head(top_n)
        )

        # Gráfico de barras
        ax.bar(
            value_counts.index,
            value_counts.values
        )

        ax.set_title(f"Valores únicos - {col}")
        ax.set_xlabel("Valor")
        ax.set_ylabel("Frecuencia")

        # Rotar labels
        ax.tick_params(axis='x', rotation=45)

    # Ajustar layout
    plt.tight_layout()

    # Mostrar
    plt.show()

# %%
columns_to_plot = [
    "human_label",
    "dataset_source"
]
history_plot(df,columns_to_plot)

# %%
df["human_label"].value_counts()
# Out:
# human_label
# traffic               17581
# instrument_music      16269
# siren_alarm           10023
# gun_explosion          9104
# notifications          6736
# fight                  6417
# crying                 6219
# voice                  5494
# another_animal         5444
# domestic_activity      5368
# ambient_noise          4966
# glass_breaking         4811
# dog                    4600
# weather                4168
# breathing              3969
# car_crash              3662
# construction_noise     3433
# water                  2513
# human_activity         2440
# impact_rattle          2397
# engine                 2217
# doors                  1939
# fire                   1663
# movement                946
# Name: count, dtype: int64

# %%
from imblearn.under_sampling import RandomUnderSampler
import pandas as pd
import numpy as np

# ============================
# CONFIGURACIÓN
# ============================
RANDOM_STATE = 42
BALANCE_TEST = True # cambiarlo a True si queremos forzar test balanceado por dataset_source

# ============================
# 1. SEPARAR EN TRAIN / TEST
# ============================
train_df = df[df["split"] == "train"].copy()
test_df = df[df["split"] == "test"].copy()

# ============================
# 2. DISTRIBUCIÓN REAL EN TRAIN
# ============================
dist = train_df["human_label"].value_counts()

# ============================
# 3. CONFIGURACIÓN DESEADA (totales por clase en train)
# ============================
undersample_target = {
    "traffic": 7600,
    "instrument_music": 7000,
    "siren_alarm": 8000,
}

# Definamos aquí qué clases queremos duplicar y a qué número total apuntar
oversample_target = {
    "engine":3000,
    "doors":2400,
    "movement":1800,
    
}

# ============================
# 4a. AJUSTE AUTOMÁTICO UNDERSAMPLE (no superar lo disponible)
# ============================
for cls, target in list(undersample_target.items()):
    if cls not in dist:
        print(f"Clase no encontrada en train (undersample): {cls}. Se omite.")
        undersample_target.pop(cls)
        continue
    max_allowed = int(dist[cls])
    if target > max_allowed:
        undersample_target[cls] = max_allowed
        print(f"Ajustado undersample {cls}: {target} --> {max_allowed}")

# ============================
# 4b. AJUSTE AUTOMÁTICO OVERSAMPLE (asegurarnos de que pide más de lo que hay)
# ============================
for cls, target in list(oversample_target.items()):
    if cls not in dist:
        print(f"Clase no encontrada en train (oversample): {cls}. Se omite.")
        oversample_target.pop(cls)
        continue
    min_allowed = int(dist[cls])
    if target <= min_allowed:
        oversample_target[cls] = min_allowed
        print(f"Ajustado oversample {cls}: el target ({target}) era menor o igual al original ({min_allowed}). Se deja el original.")

# ============================
# 5. UNDERSAMPLING PROPORCIONAL POR dataset_source EN TRAIN
# ============================
sampled_parts = []
# Excluimos de la base tanto las de undersample como las de oversample para tratarlas por separado
classes_without_target = train_df.loc[
    (~train_df["human_label"].isin(undersample_target)) & 
    (~train_df["human_label"].isin(oversample_target)), :
].copy()

for cls, total_target in undersample_target.items():
    cls_df = train_df[train_df["human_label"] == cls].copy()

    source_counts = cls_df["dataset_source"].value_counts()
    source_proportions = source_counts / source_counts.sum()

    remaining = total_target
    sources = source_proportions.index.tolist()
    for i, src in enumerate(sources):
        if i == len(sources) - 1:
            n = remaining
        else:
            n = round(source_proportions[src] * total_target)
            n = min(n, int(source_counts[src]))
            remaining -= n

        src_cls_df = cls_df[cls_df["dataset_source"] == src]
        n = min(n, len(src_cls_df))
        sampled_parts.append(
            src_cls_df.sample(n=n, random_state=RANDOM_STATE)
        )

# ============================
# 5b. OVERSAMPLING PROPORCIONAL POR dataset_source EN TRAIN (duplicación equitativa)
# ============================
for cls, total_target in oversample_target.items():
    cls_df = train_df[train_df["human_label"] == cls].copy()

    source_counts = cls_df["dataset_source"].value_counts()
    source_proportions = source_counts / source_counts.sum()

    remaining = total_target
    sources = source_proportions.index.tolist()
    for i, src in enumerate(sources):
        if i == len(sources) - 1:
            n = remaining
        else:
            n = round(source_proportions[src] * total_target)
            remaining -= n

        src_cls_df = cls_df[cls_df["dataset_source"] == src]
        
        # Si la proporción pide muestras, pero este subgrupo vino vacío originalmente, saltamos
        if len(src_cls_df) == 0 and n > 0:
            continue
            
        # Activamos 'replace=True' solo si n supera lo que hay en este dataset_source específico
        should_replace = n > len(src_cls_df)
        
        sampled_parts.append(
            src_cls_df.sample(n=n, random_state=RANDOM_STATE, replace=should_replace)
        )

# Unir clases resampleadas (under y over) + clases sin tocar
train_resampled = pd.concat(
    sampled_parts + [classes_without_target], ignore_index=True
).copy()
train_resampled["split"] = "train"

print("\nResampling (Under + Over) proporcional por dataset_source completado:")
print(f"Original train: {len(train_df)} --> Final train: {len(train_resampled)}")
print("\nDistribución train final por human_label:")
print(train_resampled["human_label"].value_counts().sort_index())
print("\nDistribución train final por (dataset_source, human_label):")
print(
    train_resampled.groupby(["dataset_source", "human_label"])
    .size()
    .reset_index(name="count")
    .sort_values(["dataset_source", "human_label"])
)

# ============================
# 6. TEST (las condiciones de test se quedan igual)
# ============================
if BALANCE_TEST:
    print("\nBALANCE_TEST=True: balanceando test proporcionalmente por dataset_source.")

    test_class_counts = test_df["human_label"].value_counts()
    min_class_size = int(test_class_counts.min())
    print(f"Tamaño objetivo por clase en test: {min_class_size}")

    test_sampled_parts = []
    for cls in test_class_counts.index:
        cls_df = test_df[test_df["human_label"] == cls].copy()

        source_counts = cls_df["dataset_source"].value_counts()
        source_proportions = source_counts / source_counts.sum()

        remaining = min_class_size
        sources = source_proportions.index.tolist()
        for i, src in enumerate(sources):
            if i == len(sources) - 1:
                n = remaining
            else:
                n = round(source_proportions[src] * min_class_size)
                n = min(n, int(source_counts[src]))
                remaining -= n

            src_cls_df = cls_df[cls_df["dataset_source"] == src]
            n = min(n, len(src_cls_df))
            test_sampled_parts.append(
                src_cls_df.sample(n=n, random_state=RANDOM_STATE)
            )

    test_resampled = pd.concat(test_sampled_parts, ignore_index=True).copy()
else:
    test_resampled = test_df.copy().reset_index(drop=True)

test_resampled["split"] = "test"

# ============================
# 7. CONCATENAR FINAL
# ============================
df_final = pd.concat([train_resampled, test_resampled], ignore_index=True)

print("\nDataFrame final:")
print(f"- Shape: {df_final.shape}")
print(f"- Train: {(df_final['split'] == 'train').sum()}")
print(f"- Test: {(df_final['split'] == 'test').sum()}\n")

print("Distribución final por split, dataset_source y human_label:")
print(
    df_final
    .groupby(["split", "dataset_source", "human_label"])
    .size()
    .reset_index(name="count")
    .sort_values(["split", "dataset_source", "human_label"])
)

# ============================
# 8. GUARDAR
# ============================
df_final.to_csv(RAW_DIR / "dataset_final_resampled.csv", index=False)
print(f"\nGuardado en: {RAW_DIR / 'dataset_final_resampled.csv'}")
# Out:
# ✅ Resampling (Under + Over) proporcional por dataset_source completado:
#    Original train: 109797 → Final train: 97499
#
# 📌 Distribución train final por human_label:
# human_label
# ambient_noise         4237
# another_animal        4570
# breathing             3323
# car_crash             3048
# construction_noise    2718
# crying                5182
# dog                   3935
# domestic_activity     3909
# doors                 2400
# engine                3000
# fight                 5162
# fire                  1487
# glass_breaking        3829
# gun_explosion         7311
# human_activity        1994
# impact_rattle         1801
# instrument_music      7000
# movement              1800
# notifications         5726
# siren_alarm           8000
# traffic               7600
# voice                 4080
# water                 1930
# weather               3457
# Name: count, dtype: int64
#
# 📌 Distribución train final por (dataset_source, human_label):
#    dataset_source     human_label  count
# 0           ESC50       breathing     30
# 1           ESC50          engine     57
# 2           ESC50            fire     34
# 3           ESC50  glass_breaking     29
# 4           ESC50        movement     91
# ..            ...             ...    ...
# 72         zenodo     siren_alarm    349
# 73         zenodo         traffic   1041
# 74         zenodo           voice   3230
# 75         zenodo           water   1930
# 76         zenodo         weather   1521
#
# [77 rows x 3 columns]
#
# ⚠️ BALANCE_TEST=True: balanceando test proporcionalmente por dataset_source.
#    Tamaño objetivo por clase en test: 176
#
# 📊 DataFrame final:
#    Shape: (101723, 20)
#    Train: 97499
#    Test:  4224
#
# 📌 Distribución final por split, dataset_source y human_label:
#      split dataset_source     human_label  count
# 0     test          ESC50       breathing      3
# 1     test          ESC50          engine      3
# 2     test          ESC50            fire      6
# 3     test          ESC50  glass_breaking      2
# 4     test          ESC50        movement      3
# ..     ...            ...             ...    ...
# 144  train         zenodo     siren_alarm    349
# 145  train         zenodo         traffic   1041
# 146  train         zenodo           voice   3230
# 147  train         zenodo           water   1930
# 148  train         zenodo         weather   1521
#
# [149 rows x 4 columns]
#
# 💾 Guardado en: /home/andres/Documentos/proyecto4geeks/data/raw/dataset_final_resampled.csv

# %%
columns_to_plot = [
    "human_label",
]
history_plot(df_final,columns_to_plot)

# %%
df_final["alertable"].value_counts()
# Out:
# alertable
# False    51691
# True     50032
# Name: count, dtype: int64

# %%
counts = df_final["alertable"].value_counts()

plt.figure(figsize=(6,4))

plt.bar(
    counts.index,
    counts.values,
)

plt.title("Distribución Alertable")
plt.show()
