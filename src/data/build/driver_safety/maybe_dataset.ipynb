# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_regression
from src.utils.config import *

# %%
# Cargamos el dataset
total_data = pd.read_csv(BUILD_DIR / 'driver_safety'/'test.tsv', delimiter="\t")
total_data.head()
# Out:
#    Unnamed: 0  filename event_label     onset     offset
# 0           0  1096.wav   TrainHorn  3.400752   7.143468
# 1           1  1096.wav       Cough  7.608028  10.000000
# 2           2  1096.wav    BoatHorn  7.969591   9.129659
# 3           3   960.wav   TruckHorn  1.829004   4.335224
# 4           4   960.wav      Sneeze  4.990897   5.951510

# %%
total_data["event_label"].value_counts()
# Out:
# event_label
# Ambulance              341
# Speech                 336
# CarHorn                330
# Cry                    329
# TrainHorn              321
# TruckHorn              321
# Vibrating              321
# Police                 317
# Firefighters           316
# Sneeze                 314
# Notifications          311
# Cough                  304
# BoatHorn               303
# Dog                    299
# Cat                    299
# Yawn                   293
# RingTone               277
# Window                  85
# Truck                   80
# Train                   78
# Crash                   76
# Rain                    76
# Drink                   76
# Hail                    75
# ManipulatingObjects     75
# Sing                    74
# Motorcyle               73
# Hit                     73
# Airplane                72
# Thunder                 72
# Drift                   71
# Wiper                   70
# Scream                  70
# MicrophoneNoise         69
# Door                    68
# Helicopter              67
# Laughter                66
# Music                   64
# Car                     63
# Ignition                62
# WarningBeeps            61
# Name: count, dtype: int64
